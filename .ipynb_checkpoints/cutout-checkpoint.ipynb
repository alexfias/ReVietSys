# %%
import atlite
import pypsa

# %%
atlite.__file__
# Out:
# '/home/vres/py/atlite/atlite/__init__.pyc'

# %%
atlite.cutout??

# %%
cutout = atlite.Cutout("vietnam-2015-2016-era5",
                       module='era5',
                       bounds=[100,6, 112,25],
                       years=slice(2015,2016, None))
cutout.prepare()
# Out:
# INFO:atlite.cutout:Cutout vietnam-2015-2016-era5 not found in directory /home/vres/data/cutouts, building new one
# 2018-07-03 13:13:13 ECMWF API python library 1.5.0
# 2018-07-03 13:13:13 ECMWF API at https://api.ecmwf.int/v1
# 2018-07-03 13:13:14 Welcome Fabian Hofmann
# 2018-07-03 13:13:14 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Web-API+Troubleshooting or contact servicedesk@ecmwf.int
# 2018-07-03 13:13:14 In case of delays, please check  service activity page http://apps.ecmwf.int/webapi-activity/
# 2018-07-03 13:13:14 Request submitted
# 2018-07-03 13:13:14 Request id: 5b3b5a4a12b43805a11c2fe4
# 2018-07-03 13:13:14 Request is queued
# Calling 'nice mars /tmp/e0/26/tmp-_marsc8ziLh.req'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# ...

# %%
cutout = atlite.Cutout("vietnam-2015-2016-ncep", 
                       module='ncep', 
                       bounds=[100,6, 112,25],
                       years=slice(2015,2016, None))
cutout.prepare(nprocesses=2)
# Out:
# INFO:atlite.cutout:Cutout vietnam-2015-2016-ncep not found in directory /home/vres/data/cutouts, building new one
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d490d8852106> in <module>()
#       2                        module='ncep',
#       3                        bounds=[100,6, 112,25],
# ----> 4                        years=slice(2015,2016, None))
#       5 cutout.prepare(nprocesses=2)
#
# /home/vres/py/atlite/atlite/cutout.pyc in __init__(self, name, cutout_dir, **cutoutparams)
#      86             if {"xs", "ys", "years"}.difference(cutoutparams):
#      87                 raise TypeError("Arguments `xs`, `ys` and `years` need to be specified")
# ---> 88             self.meta = self.get_meta(**cutoutparams)
#      89
#      90     def datasetfn(self, *args):
#
# ...
