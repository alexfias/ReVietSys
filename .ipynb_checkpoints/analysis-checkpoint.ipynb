# %%
import pypsa 
import atlite 
import vresutils.shapes as vshapes
from vresutils.graph import voronoi_partition_pts
import geopandas as gpd
#import powerplantmatching as pm
import pandas as pd
from scipy.spatial import KDTree
import numpy as np
import geopandas as gpd

from pypsa.opt import Constraint as Con

import matplotlib.pyplot as plt
# %matplotlib inline
import xarray as xr

# %%
# !hostname
# Out:
# resi

# %% [markdown]
# # Plots

# %% [markdown]
# ## Devplan

# %% [markdown]
# ### Connected

# %%
n1 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/devplan_2020/')
n2 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/devplan_2025/')
n3 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/devplan_2030/')

colors = dict(zip(['ocgt', 'wind', 'solar', 'hydro', 'hard coal', 'oil', 'bioenergy', 'nuclear', 'perpetuum'],
                  ['blue', 'green', 'yellow', 'navy', 'brown', 'black', 'darkgreen', 'lime', 'pink']))

bus_scale = 1e4
link_scale = 1e3

#%%
capas = n1.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n1.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n1.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas1 = capas
plotlines1 = lines

capas = n2.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n2.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n2.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas2 = capas
plotlines2 = lines

capas = n3.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n3.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n3.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas3 = capas
plotlines3 = lines
# Out:
# INFO:pypsa.io:Imported network  has buses, carriers, generators, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, lines, loads, storage_units

# %%
plotcapas1.sum(level=0).max(), plotcapas2.sum(level=0).max(), plotcapas3.sum(level=0).max()
# Out:
# (4948.2280858635258, 8496.5543187349758, 14746.290290585001)

# %%
plotlines1.sum(level=0).max(), plotlines2.sum(level=0).max(), plotlines3.sum(level=0).max()
# Out:
# (5642.808938317, 6867.8636540950001, 8911.0972292200004)

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1,3, figsize=(15,15))
n1.plot(bus_sizes=plotcapas1/bus_scale, bus_colors=colors, ax=ax1,
             line_widths={'Link':0.0, 'Line':plotlines1/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='DevPlan2020')
n2.plot(bus_sizes=plotcapas2/bus_scale, bus_colors=colors, ax=ax2,
             line_widths={'Link':0.0, 'Line':plotlines2/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='DevPlan2025')
n3.plot(bus_sizes=plotcapas3/bus_scale, bus_colors=colors, ax=ax3,
             line_widths={'Link':0.0, 'Line':plotlines3/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='DevPlan2030')


fig.savefig(filename='/home/vres/data/ReVietSys/fias-model_era5-data/plots/devplan_all.pdf',
            bbox_inches='tight')

# %%
n1.objective/1e9, n2.objective/1e9, n3.objective/1e9
# Out:
# (5.8520061300400004, 9.3238264117900016, 13.846294482799999)

# %%
n1_dev = n1; n2_dev = n2; n3_dev = n3

# %% [markdown]
# ### Disconnected

# %%
n1 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/devplan_2020/')
n2 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/devplan_2025/')
n3 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/devplan_2030/')

colors = dict(zip(['ocgt', 'wind', 'solar', 'hydro', 'hard coal', 'oil', 'bioenergy', 'nuclear', 'perpetuum'],
                  ['blue', 'green', 'yellow', 'navy', 'brown', 'black', 'darkgreen', 'lime', 'pink']))

bus_scale = 1e4
link_scale = 1e3

#%%
capas = n1.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n1.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n1.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas1 = capas
plotlines1 = lines

capas = n2.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n2.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n2.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas2 = capas
plotlines2 = lines

capas = n3.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n3.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n3.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas3 = capas
plotlines3 = lines
# Out:
# INFO:pypsa.io:Imported network  has buses, carriers, generators, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, lines, loads, storage_units

# %%
plotcapas1.sum(level=0).max(), plotcapas2.sum(level=0).max(), plotcapas3.sum(level=0).max()
# Out:
# (5023.9582167868639, 7986.7800624199581, 14762.636874170999)

# %%
plotlines1.sum(level=0).max(), plotlines2.sum(level=0).max(), plotlines3.sum(level=0).max()
# Out:
# (5360.3186440190002, 6923.4868071450001, 8074.9402673299992)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,15))
axes = axes.flatten()
n1.plot(bus_sizes=plotcapas1/bus_scale, bus_colors=colors, ax=axes[0],
             line_widths={'Link':0.0, 'Line':plotlines1/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='DevPlan2020')
n2.plot(bus_sizes=plotcapas2/bus_scale, bus_colors=colors, ax=axes[1],
             line_widths={'Link':0.0, 'Line':plotlines2/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='DevPlan2025')
n3.plot(bus_sizes=plotcapas3/bus_scale, bus_colors=colors, ax=axes[2],
             line_widths={'Link':0.0, 'Line':plotlines3/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='DevPlan2030')


fig.savefig(filename='/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/plots/devplan_all.pdf',
            bbox_inches='tight')

# %%
n1.objective/1e9, n2.objective/1e9, n3.objective/1e9
# Out:
# (5.8739590978000003, 9.3244646148099992, 13.890811247)

# %% [markdown]
# ## Renewable

# %% [markdown]
# ### Connected

# %%
n1 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/renewable_2020/')
n2 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/renewable_2025/')
n3 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/renewable_2030/')

colors = dict(zip(['ocgt', 'wind', 'solar', 'hydro', 'hard coal', 'oil', 'bioenergy', 'nuclear', 'perpetuum'],
                  ['blue', 'green', 'yellow', 'navy', 'brown', 'black', 'darkgreen', 'lime', 'pink']))

bus_scale = 1e5
link_scale = 1e4

#%%
capas = n1.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n1.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n1.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas1 = capas
plotlines1 = lines

capas = n2.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n2.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n2.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas2 = capas
plotlines2 = lines

capas = n3.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n3.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n3.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas3 = capas
plotlines3 = lines
# Out:
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units

# %%
plotcapas1.sum(level=0).max(), plotcapas2.sum(level=0).max(), plotcapas3.sum(level=0).max()
# Out:
# (104488.62444997954, 196061.13213647893, 249572.452632456)

# %%
plotlines1.sum(level=0).max(), plotlines2.sum(level=0).max(), plotlines3.sum(level=0).max()
# Out:
# (37570.784944109997, 51454.857043600001, 59672.320322900006)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,15))
axes = axes.flatten()
n1.plot(bus_sizes=plotcapas1/bus_scale, bus_colors=colors, ax=axes[0],
             line_widths={'Link':0.0, 'Line':plotlines1/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='Renwable2020')
n2.plot(bus_sizes=plotcapas2/bus_scale, bus_colors=colors, ax=axes[1],
             line_widths={'Link':0.0, 'Line':plotlines2/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='Renwable2025')
n3.plot(bus_sizes=plotcapas3/bus_scale, bus_colors=colors, ax=axes[2],
             line_widths={'Link':0.0, 'Line':plotlines3/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='Renwable2030')


fig.savefig(filename='/home/vres/data/ReVietSys/fias-model_era5-data/plots/renewable_all.pdf',
            bbox_inches='tight')

# %%
n1.objective/1e9, n2.objective/1e9, n3.objective/1e9
# Out:
# (0.14530107541799997, 0.25473053109499999, 0.46216299427999996)

# %%
n1_ren = n1; n2_ren = n2; n3_ren = n3

# %% [markdown]
# ### Disconnected

# %%
n1 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/renewable_2020/')
n2 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/renewable_2025/')
n3 = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/renewable_2030/')

colors = dict(zip(['ocgt', 'wind', 'solar', 'hydro', 'hard coal', 'oil', 'bioenergy', 'nuclear', 'perpetuum'],
                  ['blue', 'green', 'yellow', 'navy', 'brown', 'black', 'darkgreen', 'lime', 'pink']))

bus_scale = 1e5
link_scale = 1e4

#%%
capas = n1.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n1.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n1.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas1 = capas
plotlines1 = lines

capas = n2.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n2.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n2.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas2 = capas
plotlines2 = lines

capas = n3.generators.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
stores = n3.storage_units.groupby(['bus','carrier']).p_nom_opt.mean().fillna(0.)
lines = n3.lines.groupby(['bus0', 'bus1']).s_nom_opt.mean().fillna(0.)
capas = capas.loc[capas.index.levels[0][capas.groupby(level='bus').sum()!=0],:]
capas = capas.unstack(level=1)
capas['hydro'] = stores.unstack(level=1)
capas = capas.stack(level=0)
plotcapas3 = capas
plotlines3 = lines
# Out:
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units

# %%
plotcapas1.sum(level=0).max(), plotcapas2.sum(level=0).max(), plotcapas3.sum(level=0).max()
# Out:
# (148872.37894050463, 196319.76304928513, 233097.56538331188)

# %%
plotlines1.sum(level=0).max(), plotlines2.sum(level=0).max(), plotlines3.sum(level=0).max()
# Out:
# (18406.577794889999, 23756.96909672, 35804.018658429995)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,15))
axes = axes.flatten()
n1.plot(bus_sizes=plotcapas1/bus_scale, bus_colors=colors, ax=axes[0],
             line_widths={'Link':0.0, 'Line':plotlines1/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='Renwable2020')
n2.plot(bus_sizes=plotcapas2/bus_scale, bus_colors=colors, ax=axes[1],
             line_widths={'Link':0.0, 'Line':plotlines2/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='Renwable2025')
n3.plot(bus_sizes=plotcapas3/bus_scale, bus_colors=colors, ax=axes[2],
             line_widths={'Link':0.0, 'Line':plotlines3/link_scale},
             line_colors={'Link':'purple', 'Line':'indianred'},
             title='Renwable2030')


fig.savefig(filename='/home/vres/data/ReVietSys/fias-model_era5-data-disconnected/plots/renewable_all.pdf',
            bbox_inches='tight')

# %%
n1.objective/1e9, n2.objective/1e9, n3.objective/1e9
# Out:
# (0.20984661617299999, 0.36943896999699999, 0.66911452114500003)

# %% [markdown]
# # Data

# %%
n = pypsa.Network('/home/vres/data/ReVietSys/fias-model_era5-data/renewable_2020/')
# Out:
# INFO:pypsa.io:Imported network  has buses, carriers, generators, global_constraints, lines, loads, storage_units

# %%
pypsa.__file__
# Out:
# '/home/vres/py/PyPSA/pypsa/__init__.py'

# %% [markdown]
# # Costs

# %%
n3_dev.objective / 1e9
# Out:
# 13.846294482799999

# %%
n3_ren.objective / 1e9
# Out:
# 0.46216299427999996

# %%
mar_generator = (n3_dev.generators['marginal_cost'] * n3_dev.generators_t.p).sum(axis=0).sum() / 1e9

cap_generator = (n3_dev.generators['capital_cost'] * n3_dev.generators.p_nom_opt).sum() / 1e9

mar_storage = (n3_dev.storage_units['marginal_cost'] * n3_dev.storage_units_t.p).sum(axis=0).sum() / 1e9

cap_storage = (n3_dev.storage_units['capital_cost'] * n3_dev.storage_units.p_nom_opt).sum() / 1e9

#cap_links = (n3_dev.links['capital_cost'] * n3_dev.links['length'] * n3_dev.links['p_nom_opt'] / 1e3).sum() / 1e9
# From KW -> MW

cap_lines = (n3_dev.lines['capital_cost'] * n3_dev.lines['length'] * n3_dev.lines['s_nom_opt'] / 1e3).sum() / 1e9
# From KW -> MW

mar_generator + cap_generator + mar_storage + cap_storage + cap_links + cap_lines
# Out:
# 13.824591650896867

# %%
mar_generator = (n3_ren.generators['marginal_cost'] * n3_ren.generators_t.p).sum(axis=0).sum() / 1e9

cap_generator = (n3_ren.generators['capital_cost'] * n3_ren.generators.p_nom_opt).sum() / 1e9

mar_storage = (n3_ren.storage_units['marginal_cost'] * n3_ren.storage_units_t.p).sum(axis=0).sum() / 1e9

cap_storage = (n3_ren.storage_units['capital_cost'] * n3_ren.storage_units.p_nom_opt).sum() / 1e9

#cap_links = (n3_ren.links['capital_cost'] * n3_ren.links['length'] * n3_ren.links['p_nom_opt'] / 1e3).sum() / 1e9
# From KW -> MW

cap_lines = (n3_ren.lines['capital_cost'] * n3_ren.lines['length'] * n3_ren.lines['s_nom_opt'] / 1e3).sum() / 1e9
# From KW -> MW

mar_generator + cap_generator + mar_storage + cap_storage + cap_links + cap_lines
# Out:
# 0.4328853572747195

# %%
n3_dev.generators.groupby(['carrier','capital_cost']).mean()
# Out:
#                         marginal_cost       p_nom  p_nom_extendable  \
# carrier   capital_cost
# bioenergy 256.00               72.900    0.478261              True
# hard coal 222.00               30.000  294.021739              True
# nuclear   455.10               10.400    0.000000              True
# ocgt      63.80                76.800  168.130435              True
# oil       255.30               91.600   19.891304              True
# perpetuum 1000000.00      1000000.000    0.000000              True
# solar     65.92                 0.010    0.000000              True
# wind      140.40                0.015    4.086957              True
#
#                            p_nom_max   p_nom_min  weight    p_nom_opt  \
# carrier   capital_cost
# bioenergy 256.00                 inf    0.478261     1.0    33.645652
# hard coal 222.00                 inf  294.021739     1.0  1322.391304
# nuclear   455.10                 inf    0.000000     1.0     0.000000
# ocgt      63.80                  inf  168.130435     1.0   371.739130
# oil       255.30                 inf   19.891304     1.0    43.982609
# perpetuum 1000000.00             inf    0.000000     1.0     0.000000
# solar     65.92         1.310552e+06    0.000000     1.0   286.956522
# wind      140.40        7.709129e+04    4.086957     1.0   143.478261
#
#                         p_min_pu  p_max_pu  p_set          ...           \
# carrier   capital_cost                                     ...
# bioenergy 256.00             0.0       1.0    0.0          ...
# hard coal 222.00             0.0       1.0    0.0          ...
# nuclear   455.10             0.0       1.0    0.0          ...
# ocgt      63.80              0.0       1.0    0.0          ...
# oil       255.30             0.0       1.0    0.0          ...
# perpetuum 1000000.00         0.0       1.0    0.0          ...
# solar     65.92              0.0       1.0    0.0          ...
# wind      140.40             0.0       1.0    0.0          ...
#
#                         committable  start_up_cost  shut_down_cost  \
# carrier   capital_cost
# bioenergy 256.00              False            0.0             0.0
# hard coal 222.00              False            0.0             0.0
# nuclear   455.10              False            0.0             0.0
# ocgt      63.80               False            0.0             0.0
# oil       255.30              False            0.0             0.0
# perpetuum 1000000.00          False            0.0             0.0
# solar     65.92               False            0.0             0.0
# wind      140.40              False            0.0             0.0
#
#                         min_up_time  min_down_time  initial_status  \
# carrier   capital_cost
# bioenergy 256.00                  0              0               1
# hard coal 222.00                  0              0               1
# nuclear   455.10                  0              0               1
# ocgt      63.80                   0              0               1
# oil       255.30                  0              0               1
# perpetuum 1000000.00              0              0               1
# solar     65.92                   0              0               1
# wind      140.40                  0              0               1
#
#                         ramp_limit_up  ramp_limit_down  ramp_limit_start_up  \
# carrier   capital_cost
# bioenergy 256.00                  NaN              NaN                  1.0
# hard coal 222.00                  NaN              NaN                  1.0
# nuclear   455.10                  NaN              NaN                  1.0
# ocgt      63.80                   NaN              NaN                  1.0
# oil       255.30                  NaN              NaN                  1.0
# perpetuum 1000000.00              NaN              NaN                  1.0
# solar     65.92                   NaN              NaN                  1.0
# wind      140.40                  NaN              NaN                  1.0
#
#                         ramp_limit_shut_down
# carrier   capital_cost
# bioenergy 256.00                         1.0
# hard coal 222.00                         1.0
# nuclear   455.10                         1.0
# ocgt      63.80                          1.0
# oil       255.30                         1.0
# perpetuum 1000000.00                     1.0
# solar     65.92                          1.0
# wind      140.40                         1.0
#
# [8 rows x 23 columns]

# %%
mar_generator = (n3_dev.generators['marginal_cost'] * n3_dev.generators_t.p).sum(axis=0) / 1e9
mar_generator
# Out:
# CauBong bioenergy      6.580520e-03
# CauBong hard coal      9.121618e-01
# CauBong nuclear        0.000000e+00
# CauBong ocgt           1.468466e-03
# CauBong oil            0.000000e+00
# CauBong perpetuum      0.000000e+00
# CauBong solar          0.000000e+00
# CauBong wind           0.000000e+00
# ChonThanh bioenergy    1.370562e-03
# ChonThanh hard coal    3.561610e-01
# ChonThanh nuclear      0.000000e+00
# ChonThanh ocgt         5.200601e-05
# ChonThanh oil          0.000000e+00
# ChonThanh perpetuum    0.000000e+00
# ChonThanh solar        0.000000e+00
# ChonThanh wind         0.000000e+00
# CongThanh bioenergy    0.000000e+00
# CongThanh hard coal    2.582363e-01
# CongThanh nuclear      0.000000e+00
# CongThanh ocgt         3.827418e-03
# CongThanh oil          0.000000e+00
# CongThanh perpetuum    0.000000e+00
# CongThanh solar        0.000000e+00
# CongThanh wind         0.000000e+00
# CuChi bioenergy        2.147174e-03
# CuChi hard coal        5.287996e-01
# CuChi nuclear          0.000000e+00
# CuChi ocgt             2.525892e-03
# CuChi oil              0.000000e+00
# CuChi perpetuum        0.000000e+00
#                            ...
# VietTri nuclear        0.000000e+00
# VietTri ocgt           2.604561e-03
# VietTri oil            0.000000e+00
# VietTri perpetuum      0.000000e+00
# VietTri solar          0.000000e+00
# VietTri wind           0.000000e+00
# VinhTan bioenergy      0.000000e+00
# VinhTan hard coal      3.008055e-01
# VinhTan nuclear        0.000000e+00
# VinhTan ocgt           2.250896e-03
# VinhTan oil            0.000000e+00
# VinhTan perpetuum      0.000000e+00
# VinhTan solar          2.214129e-04
# VinhTan wind           4.367785e-07
# VungAng bioenergy      0.000000e+00
# VungAng hard coal      3.432338e-01
# VungAng nuclear        0.000000e+00
# VungAng ocgt           1.642042e-03
# VungAng oil            0.000000e+00
# VungAng perpetuum      0.000000e+00
# VungAng solar          0.000000e+00
# VungAng wind           0.000000e+00
# Yali bioenergy         1.208026e-02
# Yali hard coal         3.835645e-02
# Yali nuclear           0.000000e+00
# Yali ocgt              2.012470e-03
# Yali oil               0.000000e+00
# Yali perpetuum         0.000000e+00
# Yali solar             0.000000e+00
# Yali wind              0.000000e+00
# Length: 368, dtype: float64

# %%
mar_generator = (n3_ren.generators['marginal_cost'] * n3_ren.generators_t.p).sum(axis=0) / 1e9
mar_generator
# Out:
# CauBong bioenergy      0.002237
# CauBong hard coal      0.000000
# CauBong nuclear        0.000000
# CauBong ocgt           0.000000
# CauBong oil            0.000000
# CauBong perpetuum      0.000000
# CauBong solar          0.000000
# CauBong wind           0.000007
# ChonThanh bioenergy    0.002351
# ChonThanh hard coal    0.000000
# ChonThanh nuclear      0.000000
# ChonThanh ocgt         0.000000
# ChonThanh oil          0.000000
# ChonThanh perpetuum    0.000000
# ChonThanh solar        0.000000
# ChonThanh wind         0.000172
# CongThanh bioenergy    0.001613
# CongThanh hard coal    0.000018
# CongThanh nuclear      0.000000
# CongThanh ocgt         0.000000
# CongThanh oil          0.000000
# CongThanh perpetuum    0.000000
# CongThanh solar        0.000000
# CongThanh wind         0.000115
# CuChi bioenergy        0.000681
# CuChi hard coal        0.000000
# CuChi nuclear          0.000000
# CuChi ocgt             0.000000
# CuChi oil              0.000000
# CuChi perpetuum        0.000000
#                          ...
# VietTri nuclear        0.000000
# VietTri ocgt           0.000000
# VietTri oil            0.000000
# VietTri perpetuum      0.000000
# VietTri solar          0.000000
# VietTri wind           0.000000
# VinhTan bioenergy      0.003296
# VinhTan hard coal      0.000108
# VinhTan nuclear        0.000000
# VinhTan ocgt           0.000000
# VinhTan oil            0.000000
# VinhTan perpetuum      0.000000
# VinhTan solar          0.000494
# VinhTan wind           0.000159
# VungAng bioenergy      0.001006
# VungAng hard coal      0.000042
# VungAng nuclear        0.000000
# VungAng ocgt           0.000000
# VungAng oil            0.000000
# VungAng perpetuum      0.000000
# VungAng solar          0.000000
# VungAng wind           0.000482
# Yali bioenergy         0.000210
# Yali hard coal         0.000000
# Yali nuclear           0.000000
# Yali ocgt              0.000000
# Yali oil               0.000000
# Yali perpetuum         0.000000
# Yali solar             0.000000
# Yali wind              0.000000
# Length: 368, dtype: float64

# %%
n3_ren.generators['marginal_cost']
# Out:
# name
# CongThanh hard coal          30.000
# DiLinh wind                   0.015
# DongAnh hard coal            30.000
# DuyenHai hard coal           30.000
# HiepHoa hard coal            30.000
# LongPhu wind                  0.015
# MongDuong2 hard coal         30.000
# NhaBe ocgt                   76.800
# NhaBe oil                    91.600
# NhoQuan hard coal            30.000
# OMon bioenergy               72.900
# OMon ocgt                    76.800
# OMon oil                     91.600
# PhoNoi hard coal             30.000
# PhuLam oil                   91.600
# PhuMy hard coal              30.000
# PhuMy ocgt                   76.800
# Pleiku2 bioenergy            72.900
# Pleiku2 wind                  0.015
# QuangNinh hard coal          30.000
# SongMay oil                  91.600
# ThangLongT hard coal         30.000
# ThangLongT oil               91.600
# ThanhMy hard coal            30.000
# VinhTan hard coal            30.000
# VinhTan wind                  0.015
# VungAng hard coal            30.000
# CauBong wind                  0.015
# ChonThanh wind                0.015
# CongThanh wind                0.015
#                            ...
# LongPhu perpetuum       1000000.000
# LongThanh perpetuum     1000000.000
# MongDuong1 perpetuum    1000000.000
# MongDuong2 perpetuum    1000000.000
# MyTho perpetuum         1000000.000
# NamDinh1 perpetuum      1000000.000
# NghiSon perpetuum       1000000.000
# NhaBe perpetuum         1000000.000
# NhoQuan perpetuum       1000000.000
# OMon perpetuum          1000000.000
# PhoNoi perpetuum        1000000.000
# PhuLam perpetuum        1000000.000
# PhuMy perpetuum         1000000.000
# Pleiku perpetuum        1000000.000
# Pleiku2 perpetuum       1000000.000
# QuangNinh perpetuum     1000000.000
# SonLa perpetuum         1000000.000
# SonLaH perpetuum        1000000.000
# SongMay perpetuum       1000000.000
# TanDinh perpetuum       1000000.000
# TanUyen perpetuum       1000000.000
# TayHaNoi perpetuum      1000000.000
# ThangLongT perpetuum    1000000.000
# ThanhMy perpetuum       1000000.000
# ThuongTin perpetuum     1000000.000
# VanPhong perpetuum      1000000.000
# VietTri perpetuum       1000000.000
# VinhTan perpetuum       1000000.000
# VungAng perpetuum       1000000.000
# Yali perpetuum          1000000.000
# Name: marginal_cost, Length: 368, dtype: float64
